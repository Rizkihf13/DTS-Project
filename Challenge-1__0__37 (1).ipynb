# %%
import pandas as pd

# %%
menu = pd.read_csv(r'C:\Users\Tata\Downloads\archive\menu.csv')
menu.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
menu.describe(include="all")
# Out:
#             Category                                Item  Serving Size  \
# count            260                                 260           260
# unique             9                                 260           107
# top     Coffee & Tea  Strawberry Banana Smoothie (Small)  16 fl oz cup
# freq              95                                   1            45
# mean             NaN                                 NaN           NaN
# std              NaN                                 NaN           NaN
# min              NaN                                 NaN           NaN
# 25%              NaN                                 NaN           NaN
# 50%              NaN                                 NaN           NaN
# 75%              NaN                                 NaN           NaN
# max              NaN                                 NaN           NaN
#
#            Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# ...

# %%
df.Category.unique()
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
meals = menu.head(110)

calories_meals = pd.DataFrame({'Item': meals.Item, 'Calories': meals.Calories})
sort_meals = calories_meals.sort_values('Calories', ascending=False)

ax = sort_meals.plot.barh(x='Item', y='Calories', color='lightcoral', figsize=(30,50),stacked=False)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

plt.title('Calories in McDonalds Meals')
plt.ylabel('Number of Calories')
plt.xlabel('McDonalds Meals')

plt.show()

# %%
# Calories on each category

# Define dataframes for each category
Breakfast = menu.loc[menu.Category == 'Breakfast']
BeefPork = menu.loc[menu.Category == 'Beef & Pork']
ChickenFish = menu.loc[menu.Category == 'Chicken & Fish']
Salads = menu.loc[menu.Category == 'Salads']
SnacksSides = menu.loc[menu.Category == 'Snacks & Sides']
Desserts = menu.loc[menu.Category == 'Desserts'] 

# Average calories on each categories
avg_cat = [round(Breakfast['Calories'].mean(axis=0), 2), round(BeefPork['Calories'].mean(axis=0), 2), round(ChickenFish['Calories'].mean(axis=0), 2),round(Salads['Calories'].mean(axis=0), 2), round(SnacksSides['Calories'].mean(axis=0), 2), round(Desserts['Calories'].mean(axis=0),2)]

categories = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides', 'Desserts']

categories_color = [['cadetblue','darkturquoise','darkslategray','turquoise','paleturquoise','azure']]
avg_calat= pd.DataFrame({'Avg Calories': avg_cat}, index=categories)
ax = avg_calat.plot.bar(rot=0, color=categories_color, figsize=(20,8), title='Average Calories in Each Menu Category (in Cal)', legend=True)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# Category: Beverages
Beverage = menu.loc[df.Category == 'Beverages']

# %%
Beverages_Calories = pd.DataFrame({'Item' : Beverage.Item, 'Calories' : Beverage.Calories})
# Dietary Guidelines for Males 2020
Beverages_Calories['Males (19 - 20)'] = Beverages_Calories.Calories/2600
Beverages_Calories['Males (21 - 40)'] = Beverages_Calories.Calories/2400
Beverages_Calories['Males (41 - 60)'] = Beverages_Calories.Calories/2200
Beverages_Calories['Males (61 - 76)'] = Beverages_Calories.Calories/2000

# Dietary Guidelines for Females 2020
Beverages_Calories['Females (19 - 25)'] = Beverages_Calories.Calories/2000
Beverages_Calories['Females (26 - 50)'] = Beverages_Calories.Calories/1800
Beverages_Calories['Females (51 - 76)'] = Beverages_Calories.Calories/1600

Beverages_Calories
# Out:
#                                   Item  Calories  Males (19 - 20)  \
# 110          Coca-Cola Classic (Small)       140         0.053846
# 111         Coca-Cola Classic (Medium)       200         0.076923
# 112          Coca-Cola Classic (Large)       280         0.107692
# 113          Coca-Cola Classic (Child)       100         0.038462
# 114                  Diet Coke (Small)         0         0.000000
# 115                 Diet Coke (Medium)         0         0.000000
# 116                  Diet Coke (Large)         0         0.000000
# 117                  Diet Coke (Child)         0         0.000000
# 118                  Dr Pepper (Small)       140         0.053846
# 119                 Dr Pepper (Medium)       190         0.073077
# 120                  Dr Pepper (Large)       270         0.103846
# 121                  Dr Pepper (Child)       100         0.038462
# 122             Diet Dr Pepper (Small)         0         0.000000
# ...

# %%
# Beverage Average
AverageBeverage = Beverage['Calories'].mean(axis=0)

# %%
# Beverage Contribute to the caloric Males Intake
Males = [round(AverageBeverage/2600, 2), round(AverageBeverage/2400, 2), round(AverageBeverage/2200, 2),round(AverageBeverage/2000, 2)]

Age = ['Age 19-20', 'Age 21-40', 'Age 41-60', 'Age 61-76']

age_color = [['cadetblue','darkturquoise','darkslategray','turquoise','paleturquoise','azure']]
Males_Intake= pd.DataFrame({'Avg Calories': Males}, index=Age)
ax = Males_Intake.plot.bar(rot=0, color=age_color, figsize=(20,8), title='Beverage Contribute to the caloric Males Intake', legend=True)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# Beverage Contribute to the caloric Females Intake
Females = [round(AverageBeverage/2000, 2), round(AverageBeverage/1800, 2), round(AverageBeverage/1600, 2)]

Age = ['19-25 years old', '26-50 years old', '51-76 years old']

age_color = [['cadetblue','darkturquoise','darkslategray','turquoise','paleturquoise','azure']]
Females_Intake= pd.DataFrame({'Avg Calories': Females}, index=Age)
ax = Females_Intake.plot.bar(rot=0, color=age_color, figsize=(20,8), title='Beverage Contribute to the caloric Females Intake', legend=True)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# Category: Coffee & Tea
CoffeeTea = menu.loc[menu.Category == 'Coffee & Tea']

# %%
CoffeeTea_Calories = pd.DataFrame({'Item' : CoffeeTea.Item, 'Calories' : CoffeeTea.Calories})
# Dietary Guidelines for Males 2020
CoffeeTea_Calories['Males (19 - 20)'] = CoffeeTea_Calories.Calories/2600
CoffeeTea_Calories['Males (21 - 40)'] = CoffeeTea_Calories.Calories/2400
CoffeeTea_Calories['Males (41 - 60)'] = CoffeeTea_Calories.Calories/2200
CoffeeTea_Calories['Males (61 - 76)'] = CoffeeTea_Calories.Calories/2000

# Dietary Guidelines for Females 2020
CoffeeTea_Calories['Females (19 - 25)'] = CoffeeTea_Calories.Calories/2000
CoffeeTea_Calories['Females (26 - 50)'] = CoffeeTea_Calories.Calories/1800
CoffeeTea_Calories['Females (51 - 76)'] = CoffeeTea_Calories.Calories/1600

CoffeeTea_Calories
# Out:
#                                Item  Calories  Males (19 - 20)  \
# 137                Iced Tea (Small)         0         0.000000
# 138               Iced Tea (Medium)         0         0.000000
# 139                Iced Tea (Large)         0         0.000000
# 140                Iced Tea (Child)         0         0.000000
# 141               Sweet Tea (Small)       150         0.057692
# ..                              ...       ...              ...
# 227         Frappé Caramel (Medium)       550         0.211538
# 228          Frappé Caramel (Large)       670         0.257692
# 229   Frappé Chocolate Chip (Small)       530         0.203846
# 230  Frappé Chocolate Chip (Medium)       630         0.242308
# 231   Frappé Chocolate Chip (Large)       760         0.292308
#
#      Males (21 - 40)  Males (41 - 60)  Males (61 - 76)  Females (19 - 25)  \
# 137         0.000000         0.000000            0.000              0.000
# ...

# %%
# Coffee & Tea Average
AverageCoffeeTea = CoffeeTea['Calories'].mean(axis=0)

# %%
# Coffee & Tea Contribute to the caloric Males Intake
Males = [round(AverageCoffeeTea/2600, 2), round(AverageCoffeeTea/2400, 2), round(AverageCoffeeTea/2200, 2),round(AverageCoffeeTea/2000, 2)]

Age = ['Age 19-20', 'Age 21-40', 'Age 41-60', 'Age 61-76']

age_color = [['cadetblue','darkturquoise','darkslategray','turquoise','paleturquoise','azure']]
Males_Intake= pd.DataFrame({'Avg Calories': Males}, index=Age)
ax = Males_Intake.plot.bar(rot=0, color=age_color, figsize=(20,8), title='CoffeeTea Contribute to the caloric Males Intake', legend=True)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# Coffee & Tea Contribute to the caloric Females Intake
Females = [round(AverageCoffeeTea/2000, 2), round(AverageCoffeeTea/1800, 2), round(AverageCoffeeTea/1600, 2)]

Age = ['19-25 years old', '26-50 years old', '51-76 years old']

age_color = [['cadetblue','darkturquoise','darkslategray','turquoise','paleturquoise','azure']]
Females_Intake= pd.DataFrame({'Avg Calories': Females}, index=Age)
ax = Females_Intake.plot.bar(rot=0, color=age_color, figsize=(20,8), title='Coffee & Tea Contribute to the caloric Females Intake', legend=True)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# Does ordered grilled chicken instead of crispy increase a sandwich's nutritional value?

# %%
# First Let Check Which meals that ordered with Crispy Chicken and Grilled Chicken
# Crispy Chicken 

crispy_chicken = menu[menu['Item'].str.contains('Crispy Chicken')]
crispy_chicken.head()
# Out:
#           Category                                       Item    Serving Size  \
# 57  Chicken & Fish    Premium Crispy Chicken Classic Sandwich  7.5 oz (213 g)
# 59  Chicken & Fish       Premium Crispy Chicken Club Sandwich  8.8 oz (249 g)
# 61  Chicken & Fish  Premium Crispy Chicken Ranch BLT Sandwich  8.1 oz (230 g)
# 63  Chicken & Fish    Bacon Clubhouse Crispy Chicken Sandwich   10 oz (284 g)
# 65  Chicken & Fish     Southern Style Crispy Chicken Sandwich  5.6 oz (160 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 57       510                200       22.0                         33
# 59       670                300       33.0                         51
# 61       610                250       28.0                         43
# 63       750                340       38.0                         59
# 65       430                170       19.0                         29
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
# Grilled Chicken 
grilled_chicken = menu[menu['Item'].str.contains('Grilled Chicken')]
grilled_chicken.head()
# Out:
#           Category                                              Item  \
# 58  Chicken & Fish          Premium Grilled Chicken Classic Sandwich
# 60  Chicken & Fish             Premium Grilled Chicken Club Sandwich
# 62  Chicken & Fish        Premium Grilled Chicken Ranch BLT Sandwich
# 64  Chicken & Fish          Bacon Clubhouse Grilled Chicken Sandwich
# 71  Chicken & Fish  Premium McWrap Chicken & Bacon (Grilled Chicken)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 58     7 oz (200 g)       350                 80        9.0
# 60   8.3 oz (235 g)       510                180       20.0
# 62   7.6 oz (217 g)       450                130       15.0
# 64   9.5 oz (270 g)       590                230       25.0
# 71  10.7 oz (302 g)       480                170       19.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 58                         13            2.0                              9
# ...

# %%
# Exploring total calories from each category 

# Calories in Crispy Chicken 
calories_crispy = pd.DataFrame({'Item': crispy_chicken.Item, 'Calories': crispy_chicken.Calories})
sort_crispy = crispy_chicken.sort_values('Calories', ascending=True)

ax = sort_crispy.plot.barh(x='Item', y='Calories', color='lightgreen', figsize=(50,10), stacked=False)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

plt.title('Calories in Crispy Chicken')
plt.ylabel('Number of Calories')
plt.xlabel('McDonalds Menu')

plt.show()

# %%
# Calories in Grilled Chicken 

calories_grilled = pd.DataFrame({'Item': grilled_chicken.Item, 'Calories': grilled_chicken.Calories})
sort_grilled = grilled_chicken.sort_values('Calories', ascending=True)

ax = sort_grilled.plot.barh(x='Item', y='Calories', color='lightblue', stacked=False, figsize=(50,10))
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

plt.title('Calories in Grilled Chicken')
plt.ylabel('Number of Calories')
plt.xlabel('McDonalds Menu')

plt.show()

# %%
# Average calories on Crispy Chicken & Grilled Category
avg_crispy_cal = round(crispy_chicken.Calories.mean(axis=0), 2)
avg_grilled_cal = round(grilled_chicken.Calories.mean(axis=0), 2)

# Get visual comparison of Crispy vs Grilled Chicken
avg_cal = pd.DataFrame({'Categories':['Crispy Chicken', 'Grilled Chicken'], 'Avg Calories': [avg_crispy_cal, avg_grilled_cal]})
ax = avg_cal.plot.bar(x = 'Categories', y = 'Avg Calories', figsize=(7,5))
ax.set_title("Average Calories on Crispy Chicken and Grilled Chicken Menu Categories (in Cal)")
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# Get amount of Cholesterol in Crispy Chicken & Grilled Chicken 
# Crispy Chicken Cholesterol
crispy_cholesterol = pd.DataFrame({'Item': crispy_chicken.Item, 'Cholesterol': crispy_chicken.Cholesterol})

crispy_cholesterol_sort = crispy_cholesterol.sort_values('Cholesterol', ascending=False) #sort by sodium amount
ax = crispy_cholesterol_sort.plot.barh(x='Item', y='Cholesterol', stacked=False, figsize= (10,15), color='yellow')
ax.set_title("Total Cholesterol in Crispy Chicken Menu Category (in mg)")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Grilled Chicken Cholesterol
grilled_cholesterol = pd.DataFrame({'Item': grilled_chicken.Item, 'Cholesterol': grilled_chicken.Cholesterol})

grilled_cholesterol_sort = grilled_cholesterol.sort_values('Cholesterol', ascending=False) #sort by sodium amount
ax = grilled_cholesterol_sort.plot.barh(x='Item', y='Cholesterol', stacked=False, figsize= (10,15), color='orange')
ax.set_title("Total Cholesterol in Grilled Chicken Menu Category (in mg)")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Get amount of Sodium in Crispy Chicken & Grilled Chicken 
# Crispy Chicken Sodium
crispy_sodium = pd.DataFrame({'Item': crispy_chicken.Item, 'Sodium': crispy_chicken.Sodium})

crispy_sodium_sort = crispy_sodium.sort_values('Sodium', ascending=False) #sort by sodium amount
ax = crispy_sodium_sort.plot.barh(x='Item', y='Sodium', stacked=False, figsize= (10,15), color='thistle')
ax.set_title("Total Sodium in Crispy Chicken Menu Category (in mg)")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Grilled Chicken Sodium
grilled_sodium = pd.DataFrame({'Item': grilled_chicken.Item, 'Sodium': grilled_chicken.Sodium})

grilled_sodium_sort = grilled_sodium.sort_values('Sodium', ascending=False) #sort by sodium amount
ax = grilled_sodium_sort.plot.barh(x='Item', y='Sodium', stacked=False, figsize= (10,15), color='violet')
ax.set_title("Total Sodium in Grilled Chicken Menu Category (in mg)")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Get amount of Carbohydrates in Crispy Chicken & Grilled Chicken 
# Crispy Chicken Carbohydrates
crispy_carb = pd.DataFrame({'Item': crispy_chicken.Item, 'Carbohydrates': crispy_chicken.Carbohydrates})

crispy_carb_sort = crispy_carb.sort_values('Carbohydrates', ascending=False) #sort by Carbohydrates amount
ax = crispy_carb_sort.plot.barh(x='Item', y='Carbohydrates', stacked=False, figsize= (10,15), color='salmon')
ax.set_title("Total Carbohydrates in Crispy Chicken Menu Category (in mg)")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Grilled Chicken Carbohydrates
grilled_Carbohydrates = pd.DataFrame({'Item': grilled_chicken.Item, 'Carbohydrates': grilled_chicken.Carbohydrates})

grilled_Carbohydrates_sort = grilled_Carbohydrates.sort_values('Carbohydrates', ascending=False) #sort by Carbohydrates amount
ax = grilled_Carbohydrates_sort.plot.barh(x='Item', y='Carbohydrates', stacked=False, figsize= (10,15), color='mistyrose')
ax.set_title("Total Carbohydrates in Grilled Chicken Menu Category (in mg)")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Get the amount of sugar and dietary fiber in Crispy Chicken category
crispy_sdf = pd.DataFrame({'Item': crispy_chicken.Item, 'Sugars': crispy_chicken.Sugars, 'Dietary Fiber': crispy_chicken['Dietary Fiber']})
crispy_sdf_sort = crispy_sdf.sort_values('Sugars', ascending=False) #sort by sugar amount
ax = crispy_sdf_sort.plot.barh(x='Item', y=['Sugars','Dietary Fiber'], stacked=False, figsize= (10,10), color=['moccasin', 'orange'])
ax.set_title("Total Sugars and Dietary Fiber in Crispy Chicken Menu Category (in g)")
#ax = grilled.plot.barh(stacked=True, figsize=(10, 12))
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Get the amount of sugar and dietary fiber in Grilled Chicken category
grilled_sdf = pd.DataFrame({'Item': grilled_chicken.Item, 'Sugars': grilled_chicken.Sugars, 'Dietary Fiber': grilled_chicken['Dietary Fiber']})
grilled_sdf_sort = grilled_sdf.sort_values('Sugars', ascending=False) #sort by sugar amount
ax = grilled_sdf_sort.plot.barh(x='Item', y=['Sugars','Dietary Fiber'], stacked=False, figsize= (10,10), color=['springgreen', 'seagreen'])
ax.set_title("Total Sugars and Dietary Fiber in Grilled Chicken Menu Category (in g)")
#ax = grilled.plot.barh(stacked=True, figsize=(10, 12))
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Get the amount of vitamins and minerals in Crispy Chicken category
crispy_vm = pd.DataFrame({'Item': crispy_chicken.Item, 'Vit A': crispy_chicken['Vitamin A (% Daily Value)'], 'Vit C': crispy_chicken['Vitamin C (% Daily Value)'], 'Calcium': crispy_chicken['Calcium (% Daily Value)'], 'Iron': crispy_chicken['Iron (% Daily Value)']})
crispy_vm_sort = crispy_vm.sort_values('Vit A', ascending=False) #sort by vit A amount
ax = crispy_vm_sort.plot.barh(x='Item', y=['Vit A','Vit C', 'Calcium', 'Iron'], stacked=False, figsize= (8,15), colormap='cool')
ax.set_title("Total Vitamins and Minerals in Crispy Chicken Menu Category (in %DV)")
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Get the amount of vitamins and minerals in Grilled Chicken category
grilled_vm = pd.DataFrame({'Item': grilled_chicken.Item, 'Vit A': grilled_chicken['Vitamin A (% Daily Value)'], 'Vit C': grilled_chicken['Vitamin C (% Daily Value)'], 'Calcium': grilled_chicken['Calcium (% Daily Value)'], 'Iron': grilled_chicken['Iron (% Daily Value)']})
grilled_vm_sort = grilled_vm.sort_values('Vit A', ascending=False) #sort by vit A amount
ax = grilled_vm_sort.plot.barh(x='Item', y=['Vit A','Vit C', 'Calcium', 'Iron'], stacked=False, figsize= (8,15), colormap='autumn')
ax.set_title("Total Vitamins and Minerals in Grilled Chicken Menu Category (in %DV)")
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
#Problem 4 What about ordering egg whites instead of whole eggs?

# %%
# Exploring the amount of calories on Crispy Chicken category
whites = df[df['Item'].str.contains('Egg White')]
whites_cal = pd.DataFrame({'Item': whites.Item, 'Calories': whites.Calories})
whites_sort = whites_cal.sort_values('Calories', ascending=False)
ax = whites_sort.plot.barh(x='Item', y='Calories', color='lavender', figsize= (10,7), stacked=False)
ax.set_title("Total Calories in White Eggs)")
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Exploring the amount of calories on Whole Eggs category
whole = df[df['Item'].str.contains('Egg')] 
whole = whole[~whole['Item'].str.contains('White')]
whole_cal = pd.DataFrame({'Item': whole.Item, 'Calories': whole.Calories})
whole_sort = whole_cal.sort_values('Calories', ascending=False)
ax = whole_sort.plot.barh(x='Item', y='Calories', figsize= (10,7), stacked=False, color='aqua')
ax.set_title("Total Calories in White Eggs)")
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
# Average calories on Egg Whites Category
avg_whites_cal = whites.Calories.mean(axis=0)

# Average calories on Whole Egg Category
avg_whole_cal = whole.Calories.mean(axis=0)

# Plot a bar chart for visual comparison
avg_egg_cal = [avg_whites_cal, avg_whole_cal]
index = ['Egg Whites', 'Whole Eggs']
avg_egg_cal = pd.DataFrame({'Avg Cal': avg_egg_cal,}, index=index)
ax = avg_egg_cal.plot.barh(rot=0, color='skyblue')
ax.set_title("Average Calories in Egg Whites and Whole Eggs Categories (in Cal)")
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(str(width), xy=(left+width/2, bottom+height/2), 
                horizontalalignment='left', verticalalignment='center') # Give annotation to the chart

# %%
#Problem 5 What is the least number of items could you order from the menu to meet one day's nutritional requirements?

# %%
least_number_data = menu.iloc[:,[1,6,8,11,13,15,17,20,21,22,23]]
least_number_data.describe()
# Out:
#        Total Fat (% Daily Value)  Saturated Fat (% Daily Value)  \
# count                 260.000000                     260.000000
# mean                   21.815385                      29.965385
# std                    21.885199                      26.639209
# min                     0.000000                       0.000000
# 25%                     3.750000                       4.750000
# 50%                    17.000000                      24.000000
# 75%                    35.000000                      48.000000
# max                   182.000000                     102.000000
#
#        Cholesterol (% Daily Value)  Sodium (% Daily Value)  \
# count                   260.000000              260.000000
# mean                     18.392308               20.676923
# std                      29.091653               24.034954
# min                       0.000000                0.000000
# 25%                       2.000000                4.750000
# ...

# %%
max_index=[]
for i in least_number_data.describe().columns:
    max_index.extend(least_number_data[least_number_data[i]==least_number_data.describe().loc['max',i]].index.tolist())

# %%
index_set = set(max_index)
index_list = list(index_set)

# %%
max_data = least_number_data.iloc[index_list,:]

# %%
from itertools import combinations

for i in combinations(max_data.index,6):
    table = least_number_data.iloc[list(i),:]
    l = []
    for n in max_data.columns[1:]:
        m = table[n].sum()
        l.append(m)
    if all(l>=100*np.ones(10)):
        print(i)
        break
# Out:
# (32, 89, 34, 135, 82, 246)

# %%
min_menu = least_number_data.iloc[list(i),:]
min_menu
# Out:
#                                                   Item  \
# 32         Big Breakfast with Hotcakes (Large Biscuit)
# 89        Premium Southwest Salad with Grilled Chicken
# 34   Big Breakfast with Hotcakes and Egg Whites (La...
# 135                   Minute Maid Orange Juice (Large)
# 82                        Chicken McNuggets (40 piece)
# 246                           Strawberry Shake (Large)
#
#      Total Fat (% Daily Value)  Saturated Fat (% Daily Value)  \
# 32                          93                            100
# 89                          13                             13
# 34                          77                             81
# 135                          0                              0
# 82                         182                            101
# 246                         36                             75
#
#      Cholesterol (% Daily Value)  Sodium (% Daily Value)  \
# 32                           192                      94
# ...
